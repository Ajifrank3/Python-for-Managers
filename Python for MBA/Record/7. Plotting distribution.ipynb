# %%
# Perform charts for given dataset using matplotlib
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv("C:/Users/admin/Downloads/MBA_2023_PM.csv")

# %%
df
# Out:
#          REGNO      STUDENT NAME  CLASS MAJOR  MINOR  SUB_1  SUB_2  SUB_3  \
# 0    1P23MB001           AJITH N  MBA-A     BA    AF     60     64     82
# 1    1P23MB002         AMULRAJ E  MBA-A     BA    AF     88     49     95
# 2    1P23MB003       ARUNVIJAY S  MBA-A     BA    AF     99     54     63
# 3    1P23MB004         DHANUSH N  MBA-A     BA    AF     75     68     56
# 4    1P23MB005        DHEEPIKA A  MBA-A     BA    AF     63     60     70
# ..         ...               ...    ...    ...   ...    ...    ...    ...
# 120  1P23MB121  VIJAYA KRISHNA G  MBA-B     AF    HR     71     74     85
# 121  1P23MB122        VIMALRAJ S  MBA-B     HR    AF     41     46     61
# 122  1P23MB123    VINEETHKUMAR P  MBA-B     DM    HR     57     81     83
# 123  1P23MB124         VINISHA S  MBA-B     HR    DM     85     99     82
# 124  1P23MB125            YUGI V  MBA-B     DM    HR     50     54     84
#
#      SUB_4
# 0       62
# 1       59
# 2       69
# 3       53
# 4       51
# ...

# %%
plt.plot(df['SUB_1'],df['SUB_2'])
plt.title('Marks')
plt.xlabel('SUB 1')
plt.ylabel('SUB 2')
plt.show()
