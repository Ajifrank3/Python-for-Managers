# %%
# clean the data with pandas library
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/admin/Downloads/Data_Cleaning_data.csv")

# %%
df # pandas can only recognise 'NaN' values
# Out:
#    Unnamed: 0 Temperature  Humidity
# 0         1.0           1       1.0
# 1         NaN         NaN       NaN
# 2         3.0           3      31.0
# 3         4.0           2      22.0
# 4         5.0           3      33.0
# 5         6.0           1      11.0
# 6         7.0           2      21.0
# 7         8.0         N/a      24.0
# 8         9.0           1      12.0
# 9        10.0          na      32.0

# %%
df.isnull()
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0       False        False     False
# 1        True         True      True
# 2       False        False     False
# 3       False        False     False
# 4       False        False     False
# 5       False        False     False
# 6       False        False     False
# 7       False        False     False
# 8       False        False     False
# 9       False        False     False

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     1
# Temperature    1
# Humidity       1
# dtype: int64

# %%
missing_values=["N/a","na",np.nan]

# %%
df = pd.read_csv("C:/Users/admin/Downloads/Data_Cleaning_data.csv",na_values = missing_values)

# %%
df.isnull()
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0       False        False     False
# 1        True         True      True
# 2       False        False     False
# 3       False        False     False
# 4       False        False     False
# 5       False        False     False
# 6       False        False     False
# 7       False         True     False
# 8       False        False     False
# 9       False         True     False

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     1
# Temperature    3
# Humidity       1
# dtype: int64

# %%
# removing missing values
df
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 1         NaN          NaN       NaN
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 7         8.0          NaN      24.0
# 8         9.0          1.0      12.0
# 9        10.0          NaN      32.0

# %%
df.dropna()
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 8         9.0          1.0      12.0

# %%
df.dropna(how="all")
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 7         8.0          NaN      24.0
# 8         9.0          1.0      12.0
# 9        10.0          NaN      32.0

# %%
df1 = df.fillna(0)

# %%
df1
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 1         0.0          0.0       0.0
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 7         8.0          0.0      24.0
# 8         9.0          1.0      12.0
# 9        10.0          0.0      32.0

# %%
#interpolating the values
df2 = df.interpolate()

# %%
df2
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 1         2.0          2.0      16.0
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 7         8.0          1.5      24.0
# 8         9.0          1.0      12.0
# 9        10.0          1.0      32.0

# %%
df3 = df.fillna({'Temperature':8888})

# %%
df3
# Out:
#    Unnamed: 0  Temperature  Humidity
# 0         1.0          1.0       1.0
# 1         NaN       8888.0       NaN
# 2         3.0          3.0      31.0
# 3         4.0          2.0      22.0
# 4         5.0          3.0      33.0
# 5         6.0          1.0      11.0
# 6         7.0          2.0      21.0
# 7         8.0       8888.0      24.0
# 8         9.0          1.0      12.0
# 9        10.0       8888.0      32.0
